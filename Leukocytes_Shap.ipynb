# %%
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
tf.compat.v1.disable_eager_execution()
import tensorflow.compat.v1.keras.backend as K
from __future__ import print_function
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.optimizers import Adam, SGD
import numpy as np
import pickle
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
pickle_in = open('/content/drive/MyDrive/Leukocyty/X_train.pickle', 'rb')
X_train = pickle.load(pickle_in)
pickle_in = open('/content/drive/MyDrive/Leukocyty/y_train.pickle', 'rb')
y_train = pickle.load(pickle_in)
pickle_in = open('/content/drive/MyDrive/Leukocyty/X_test.pickle', 'rb')
X_test = pickle.load(pickle_in)
pickle_in = open('/content/drive/MyDrive/Leukocyty/y_test.pickle', 'rb')
y_test = pickle.load(pickle_in)

# %%
batch_size = 32
num_classes = 4
epochs = 50

# %%
img_rows, img_cols = 224, 224

# %%
y_train = np.array(y_train)
y_test = np.array(y_test)
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
print(y_train.shape)
print(X_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1597, 4)
# (1597, 224, 224, 3)
# (193, 224, 224, 3)
# (193, 4)

# %%
K.image_data_format()
#if K.image_data_format() == 'channels_first':
#    X_train = X_train.reshape(X_train.shape[0], 1, img_rows, img_cols)
#    X_test = X_test.reshape(X_test.shape[0], 1, img_rows, img_cols)
#    input_shape = (1, img_rows, img_cols)
#else:
#    X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 1)
#    X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 1)
#    input_shape = (img_rows, img_cols, 1)
# Out:
# 'channels_last'

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (1597, 224, 224, 3)
# 1597 train samples
# 193 test samples

# %%
input_shape = (img_rows, img_cols, 3)

# %%
vgg = VGG16(input_shape = input_shape, weights='imagenet', include_top=False)

# %%
for layeer in vgg.layers:
  layeer.trainable = False

x = Flatten()(vgg.output)
x = Dense(128, activation='relu')(x)
x = Dropout(0.2)(x)
predictions = Dense(4, activation='softmax')(x)

model = Model(inputs=vgg.input, outputs=predictions)
opt = Adam(lr=0.0004)

model.compile(
  loss='categorical_crossentropy',
  optimizer=opt,
  metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3211392
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 17,926,596
# Trainable params: 3,211,908
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_test, y_test))
# Out:
# Train on 1597 samples, validate on 193 samples
# Epoch 1/50
# 1597/1597 [==============================] - ETA: 0s - loss: 9.3856 - acc: 0.3820WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_v1.py:2048: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 1597/1597 [==============================] - 8s 5ms/sample - loss: 9.3856 - acc: 0.3820 - val_loss: 6.0130 - val_acc: 0.5907
# Epoch 2/50
# 1597/1597 [==============================] - 6s 4ms/sample - loss: 5.2723 - acc: 0.6412 - val_loss: 2.6834 - val_acc: 0.8031
# Epoch 3/50
# 1597/1597 [==============================] - 6s 4ms/sample - loss: 3.5910 - acc: 0.7477 - val_loss: 2.1271 - val_acc: 0.8290
# Epoch 4/50
# 1597/1597 [==============================] - 6s 4ms/sample - loss: 3.0475 - acc: 0.7890 - val_loss: 2.3961 - val_acc: 0.8394
# Epoch 5/50
# 1597/1597 [==============================] - 6s 4ms/sample - loss: 2.6711 - acc: 0.8103 - val_loss: 2.9452 - val_acc: 0.7979
# Epoch 6/50
# 1597/1597 [==============================] - 6s 4ms/sample - loss: 2.1669 - acc: 0.8516 - val_loss: 2.4445 - val_acc: 0.8290
# Epoch 7/50
# 1597/1597 [==============================] - 6s 4ms/sample - loss: 1.9231 - acc: 0.8679 - val_loss: 1.9602 - val_acc: 0.8549
# Epoch 8/50
# 1597/1597 [==============================] - 6s 4ms/sample - loss: 1.8193 - acc: 0.8729 - val_loss: 2.9362 - val_acc: 0.8083
# Epoch 9/50
# 1597/1597 [==============================] - 6s 4ms/sample - loss: 1.7716 - acc: 0.8735 - val_loss: 2.3066 - val_acc: 0.8290
# Epoch 10/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 1.3611 - acc: 0.8986 - val_loss: 1.4162 - val_acc: 0.8808
# Epoch 11/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 1.2677 - acc: 0.9080 - val_loss: 2.2166 - val_acc: 0.8446
# Epoch 12/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 1.0429 - acc: 0.9236 - val_loss: 1.6387 - val_acc: 0.8756
# Epoch 13/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.8610 - acc: 0.9349 - val_loss: 1.2500 - val_acc: 0.9016
# Epoch 14/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.6892 - acc: 0.9487 - val_loss: 1.2002 - val_acc: 0.8912
# Epoch 15/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.6521 - acc: 0.9493 - val_loss: 1.5678 - val_acc: 0.8497
# Epoch 16/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.7130 - acc: 0.9418 - val_loss: 1.1465 - val_acc: 0.9016
# Epoch 17/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.6665 - acc: 0.9455 - val_loss: 1.0356 - val_acc: 0.9119
# Epoch 18/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.5833 - acc: 0.9537 - val_loss: 1.2491 - val_acc: 0.9067
# Epoch 19/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.4620 - acc: 0.9668 - val_loss: 1.1431 - val_acc: 0.9067
# Epoch 20/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.5187 - acc: 0.9631 - val_loss: 1.4586 - val_acc: 0.8912
# Epoch 21/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.4651 - acc: 0.9681 - val_loss: 1.3445 - val_acc: 0.8964
# Epoch 22/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.4837 - acc: 0.9624 - val_loss: 1.1532 - val_acc: 0.9016
# Epoch 23/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.4350 - acc: 0.9668 - val_loss: 0.9413 - val_acc: 0.9171
# Epoch 24/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.3492 - acc: 0.9743 - val_loss: 1.0641 - val_acc: 0.9016
# Epoch 25/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.2745 - acc: 0.9787 - val_loss: 1.0689 - val_acc: 0.9119
# Epoch 26/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.3362 - acc: 0.9699 - val_loss: 0.6084 - val_acc: 0.9378
# Epoch 27/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.2314 - acc: 0.9787 - val_loss: 0.9000 - val_acc: 0.9171
# Epoch 28/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.2126 - acc: 0.9806 - val_loss: 0.8976 - val_acc: 0.9223
# Epoch 29/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.2089 - acc: 0.9793 - val_loss: 0.8207 - val_acc: 0.9275
# Epoch 30/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.2072 - acc: 0.9787 - val_loss: 0.8304 - val_acc: 0.9067
# Epoch 31/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.1638 - acc: 0.9831 - val_loss: 1.2439 - val_acc: 0.8964
# Epoch 32/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.2049 - acc: 0.9800 - val_loss: 0.8178 - val_acc: 0.9119
# Epoch 33/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.2039 - acc: 0.9800 - val_loss: 1.1637 - val_acc: 0.8860
# Epoch 34/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.3014 - acc: 0.9743 - val_loss: 1.2976 - val_acc: 0.8756
# Epoch 35/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.1134 - acc: 0.9906 - val_loss: 1.2430 - val_acc: 0.8964
# Epoch 36/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.1834 - acc: 0.9843 - val_loss: 1.0074 - val_acc: 0.9119
# Epoch 37/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.1627 - acc: 0.9856 - val_loss: 1.2954 - val_acc: 0.8964
# Epoch 38/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.1713 - acc: 0.9837 - val_loss: 1.2904 - val_acc: 0.9016
# Epoch 39/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.1671 - acc: 0.9869 - val_loss: 1.1467 - val_acc: 0.9171
# Epoch 40/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.2296 - acc: 0.9806 - val_loss: 1.3422 - val_acc: 0.9016
# Epoch 41/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.2496 - acc: 0.9768 - val_loss: 1.2549 - val_acc: 0.9067
# Epoch 42/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.2396 - acc: 0.9818 - val_loss: 1.1791 - val_acc: 0.9171
# Epoch 43/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.1677 - acc: 0.9869 - val_loss: 1.1009 - val_acc: 0.9119
# Epoch 44/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.1634 - acc: 0.9862 - val_loss: 1.2391 - val_acc: 0.9119
# Epoch 45/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.2225 - acc: 0.9812 - val_loss: 1.7734 - val_acc: 0.8705
# Epoch 46/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.1789 - acc: 0.9869 - val_loss: 1.3757 - val_acc: 0.9067
# Epoch 47/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.1771 - acc: 0.9862 - val_loss: 1.5799 - val_acc: 0.8756
# Epoch 48/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.1834 - acc: 0.9837 - val_loss: 1.7378 - val_acc: 0.8705
# Epoch 49/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.1415 - acc: 0.9856 - val_loss: 1.2750 - val_acc: 0.9067
# Epoch 50/50
# 1597/1597 [==============================] - 7s 4ms/sample - loss: 0.1883 - acc: 0.9862 - val_loss: 1.0182 - val_acc: 0.9119

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print("CNN Error: %.2f%%" % (100-score[1]*100))
# Out:
# Test loss: 1.0181848008397971
# Test accuracy: 0.9119171
# CNN Error: 8.81%

# %%
pip install shap
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.6/dist-packages (0.37.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from shap) (0.22.2.post1)
# Requirement already satisfied: slicer==0.0.3 in /usr/local/lib/python3.6/dist-packages (from shap) (0.0.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.6/dist-packages (from shap) (0.48.0)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.6/dist-packages (from shap) (4.41.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from shap) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from shap) (1.18.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from shap) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->shap) (0.17.0)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba->shap) (0.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba->shap) (50.3.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->shap) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)

# %%
import shap

# %%
to_explain = X_test[[113, 22, 65, 178,]]
to_explain.shape
# Out:
# (4, 224, 224, 3)

# %%
def map2layer(x, layer):
    feed_dict = dict(zip([model.layers[0].input], [preprocess_input(x.copy())]))
    return K.get_session().run(model.layers[layer].input, feed_dict)

# %%
e = shap.GradientExplainer(
    (model.layers[7].input, model.layers[-1].output),
    map2layer(X_test, 7),
    local_smoothing=0 # std dev of smoothing noise
)

shap_values,indexes = e.shap_values(map2layer(to_explain, 7), ranked_outputs=4)

# %%
shap.image_plot(shap_values, to_explain, indexes)
#'EOSINOPHIL':0,'LYMPHOCYTE':1,'MONOCYTE':2, 'NEUTROPHIL':3

# %%
background = X_train[np.random.choice(X_train.shape[0], 4, replace=False)]

# %%
e = shap.DeepExplainer(model, background)
shap_values = e.shap_values(X_test[113:117])
# Out:
# keras is no longer supported, please use tf.keras instead.

# %%
shap.image_plot(shap_values, -X_test[113:117])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
